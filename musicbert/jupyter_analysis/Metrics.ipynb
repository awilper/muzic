# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import json

file_path = 'metrics.json' 
df = pd.read_json(file_path)

df.head()
# Out:
#   y_true y_pred   hotness                                              title  \
# 0      C      C  0.462081                                 b'Bad moon rising'
# 1      C      C  0.270776              b'Bring A Torch_ Jeannette_ Isabella'
# 2      C      C  0.264614             b"You're My Everything - Re-Recording"
# 4      C      H  0.000000     b'The Nutcracker Op.71-atto 2 - Chinese Dance'
# 6      H      H  0.569501  b'Pink Panther/It Had Better Be Tonight (Megli...
#
#                msd_id                           midi_id  latitude_vec  \
# 0  TRXANNA128F92EF09A  10da7f24baeab88f96550e3740f1c53a       0.00000
# 1  TRGEPST12903CCC87D  de4476c4357513ac5afd4d44a04d220f      41.26069
# 2  TRTNLNB128F92E04B1  14bef3af6db660a1c5dc2ab0fa8c505d       0.00000
# 4  TRIXYYV12903CB0502  aa6b40cd2139333190b2a92731aebfd6       0.00000
# 6  TRDPYXF128F933FD80  955dadcdb9ad6b31c4e7de12951da1b4      30.10560
#
#    longitude_vec
# 0        0.00000
# 1       41.26069
# 2        0.00000
# ...

# %%
sns.violinplot(x='y_true', y='hotness', data=df, palette={'H': 'red', 'C': 'blue'}, cut=0)
plt.show()
# Out:
# /usr/local/anaconda3/envs/analysis/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /usr/local/anaconda3/envs/analysis/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /usr/local/anaconda3/envs/analysis/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
sns.violinplot(x='y_pred', y='hotness', data=df, palette={'H': 'red', 'C': 'blue'}, cut=0)
plt.show()
# Out:
# /usr/local/anaconda3/envs/analysis/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /usr/local/anaconda3/envs/analysis/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /usr/local/anaconda3/envs/analysis/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
